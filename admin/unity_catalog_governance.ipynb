# %% [markdown]
# ### Unity CataLog Governance

# %%
# %sql
-- Engineers
GRANT ALL PRIVILEGES ON SCHEMA credit_catalog.silver TO `souravraj664@gmail.com`;

-- Data Scientists
GRANT SELECT ON SCHEMA credit_catalog.silver TO `souravraj664@gmail.com`;
GRANT ALL PRIVILEGES ON SCHEMA credit_catalog.gold TO `souravraj664@gmail.com`;

-- Analysts
GRANT SELECT ON SCHEMA credit_catalog.gold TO `souravraj664@gmail.com`;
